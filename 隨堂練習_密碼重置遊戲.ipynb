# %%
password="a108260018"
time=0

while time <=3:
    answer=input("a108260018")
    if answer==password:
      print("登入成功")
      break
else:
    times=times+1
    chance=3-times
    print("密碼錯誤!還有".chance,"次機會")
# Out:
# a108260018a108260018
# 登入成功
